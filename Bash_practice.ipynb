# %%
# %%shell
# chmod +x ./sample_data/menu.sh
# ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 May 11 01:33 drive
# drwxr-xr-x 1 root root 4096 May 11 01:38 sample_data
# ./sample_data/menu.sh: line 2: opciones: command not found
# Selecciona una opción de nuestro menu

# %%
# %%shell
# #ls
# #chmod +x ./sample_data/menus.sh
# #./sample_data/menus.sh
# #cd sample_data
# #ls
# ./sample_data/menus.sh
# Out:
# Selecciona una opción de nuestro menu
# 1) Verificar
# 2) Ensamblar
# 3) Crear_GIF
# 4) Salir
# #? 1
# Ingrese ruta de acceso a las imágenes
# /content
# La ruta existe y es: /content
# Kbytes	Archivos.png
# ls: cannot access '*.png': No such file or directory
#
# #? 1
# Ingrese ruta de acceso a las imágenes
# /content/sample_data/menus.sh
# Es una ruta...pero de un archivo
# #? 4
# Bye!
